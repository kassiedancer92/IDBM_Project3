# %% [markdown]
# #### Import Data

# %%
#Imports
import pandas as pd
import numpy as np

# %%
# import basics dataset and convert to cvs
basics = pd.read_csv("Data/title.basics_real.tsv.gz", sep='\t', low_memory=False)
basics.head()
# Out:
#       tconst titleType            primaryTitle           originalTitle  \
# 0  tt0000001     short              Carmencita              Carmencita
# 1  tt0000002     short  Le clown et ses chiens  Le clown et ses chiens
# 2  tt0000003     short          Pauvre Pierrot          Pauvre Pierrot
# 3  tt0000004     short             Un bon bock             Un bon bock
# 4  tt0000005     short        Blacksmith Scene        Blacksmith Scene
#
#   isAdult startYear endYear runtimeMinutes                    genres
# 0       0      1894      \N              1         Documentary,Short
# 1       0      1892      \N              5           Animation,Short
# 2       0      1892      \N              4  Animation,Comedy,Romance
# 3       0      1892      \N             12           Animation,Short
# 4       0      1893      \N              1              Comedy,Short

# %%
# import akas dataset and convert to cvs
akas = pd.read_csv('Data/title.akas_real.csv', low_memory=False)
akas.head()
# Out:
#      titleId  ordering                   title region language        types  \
# 0  tt0000001         6              Carmencita     US       \N  imdbDisplay
# 1  tt0000002         7  The Clown and His Dogs     US       \N           \N
# 2  tt0000005        10        Blacksmith Scene     US       \N  imdbDisplay
# 3  tt0000005         1     Blacksmithing Scene     US       \N  alternative
# 4  tt0000005         6     Blacksmith Scene #1     US       \N  alternative
#
#               attributes isOriginalTitle
# 0                     \N               0
# 1  literal English title               0
# 2                     \N               0
# 3                     \N               0
# 4                     \N               0

# %%
# import rating dataset and convert to cvs
rating = pd.read_csv("Data/title.ratings_real.tsv.gz", sep='\t', low_memory=False)
rating.head()
# Out:
#       tconst  averageRating  numVotes
# 0  tt0000001            5.7      1990
# 1  tt0000002            5.8       265
# 2  tt0000003            6.5      1869
# 3  tt0000004            5.5       177
# 4  tt0000005            6.2      2655

# %% [markdown]
# ### Replace /N with NaN

# %%
#Replace "\N" with np.nan
akas = akas.replace({'\\N':np.nan})
#Verify the change
akas.head()
# Out:
#      titleId  ordering                   title region language        types  \
# 0  tt0000001         6              Carmencita     US      NaN  imdbDisplay
# 1  tt0000002         7  The Clown and His Dogs     US      NaN          NaN
# 2  tt0000005        10        Blacksmith Scene     US      NaN  imdbDisplay
# 3  tt0000005         1     Blacksmithing Scene     US      NaN  alternative
# 4  tt0000005         6     Blacksmith Scene #1     US      NaN  alternative
#
#               attributes isOriginalTitle
# 0                    NaN               0
# 1  literal English title               0
# 2                    NaN               0
# 3                    NaN               0
# 4                    NaN               0

# %%
akas.info()

#Check to make sure the US is the only value in region
akas['region'].value_counts()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1452564 entries, 0 to 1452563
# Data columns (total 8 columns):
#  #   Column           Non-Null Count    Dtype
# ---  ------           --------------    -----
#  0   titleId          1452564 non-null  object
#  1   ordering         1452564 non-null  int64
#  2   title            1452564 non-null  object
#  3   region           1452564 non-null  object
#  4   language         4018 non-null     object
#  5   types            981678 non-null   object
#  6   attributes       47016 non-null    object
#  7   isOriginalTitle  1451222 non-null  object
# dtypes: int64(1), object(7)
# memory usage: 88.7+ MB
# US    1452564
# Name: region, dtype: int64

# %%
#Replace "\N" with np.nan
basics = basics.replace({'\\N':np.nan})
#Verify the change
basics.head()
# Out:
#       tconst titleType            primaryTitle           originalTitle  \
# 0  tt0000001     short              Carmencita              Carmencita
# 1  tt0000002     short  Le clown et ses chiens  Le clown et ses chiens
# 2  tt0000003     short          Pauvre Pierrot          Pauvre Pierrot
# 3  tt0000004     short             Un bon bock             Un bon bock
# 4  tt0000005     short        Blacksmith Scene        Blacksmith Scene
#
#   isAdult startYear endYear runtimeMinutes                    genres
# 0       0      1894     NaN              1         Documentary,Short
# 1       0      1892     NaN              5           Animation,Short
# 2       0      1892     NaN              4  Animation,Comedy,Romance
# 3       0      1892     NaN             12           Animation,Short
# 4       0      1893     NaN              1              Comedy,Short

# %%
basics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10130849 entries, 0 to 10130848
# Data columns (total 9 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   tconst          object
#  1   titleType       object
#  2   primaryTitle    object
#  3   originalTitle   object
#  4   isAdult         object
#  5   startYear       object
#  6   endYear         object
#  7   runtimeMinutes  object
#  8   genres          object
# dtypes: object(9)
# memory usage: 695.6+ MB

# %%
#Replace "\N" with np.nan
rating = rating.replace({'\\N':np.nan})
#Verify the change
rating.head()
# Out:
#       tconst  averageRating  numVotes
# 0  tt0000001            5.7      1990
# 1  tt0000002            5.8       265
# 2  tt0000003            6.5      1869
# 3  tt0000004            5.5       177
# 4  tt0000005            6.2      2655

# %%
rating.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1344601 entries, 0 to 1344600
# Data columns (total 3 columns):
#  #   Column         Non-Null Count    Dtype
# ---  ------         --------------    -----
#  0   tconst         1344601 non-null  object
#  1   averageRating  1344601 non-null  float64
#  2   numVotes       1344601 non-null  int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 30.8+ MB

# %% [markdown]
# ### Basics
#
# - Keep only US movies
#
# - Eliminate movies that are null for runtimeMinutes
#
# - Eliminate movies that are null for genre
#
# - Keep only titleType==Movie
#
# - Convert the startYear column to float data type.
#
# - Filter the dataframe using startYear. Keep years between 2000-2021 (Including 2000 and 2021)
#
# - Eliminate movies that include "Documentary" in the genre

# %%
# Filter the basics table down to only include the US by using the filter akas dataframe
keepers =basics['tconst'].isin(akas['titleId'])
keepers
#implament filter
basics = basics[keepers]
#verify changes
basics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1365230 entries, 0 to 10130804
# Data columns (total 9 columns):
#  #   Column          Non-Null Count    Dtype
# ---  ------          --------------    -----
#  0   tconst          1365230 non-null  object
#  1   titleType       1365230 non-null  object
#  2   primaryTitle    1365230 non-null  object
#  3   originalTitle   1365230 non-null  object
#  4   isAdult         1365230 non-null  object
#  5   startYear       1267582 non-null  object
#  6   endYear         37431 non-null    object
#  7   runtimeMinutes  863538 non-null   object
#  8   genres          1336825 non-null  object
# dtypes: object(9)
# memory usage: 104.2+ MB

# %%
basics.head()
# Out:
#       tconst titleType            primaryTitle           originalTitle  \
# 0  tt0000001     short              Carmencita              Carmencita
# 1  tt0000002     short  Le clown et ses chiens  Le clown et ses chiens
# 2  tt0000003     short          Pauvre Pierrot          Pauvre Pierrot
# 3  tt0000004     short             Un bon bock             Un bon bock
# 4  tt0000005     short        Blacksmith Scene        Blacksmith Scene
#
#   isAdult startYear endYear runtimeMinutes                    genres
# 0       0      1894     NaN              1         Documentary,Short
# 1       0      1892     NaN              5           Animation,Short
# 2       0      1892     NaN              4  Animation,Comedy,Romance
# 3       0      1892     NaN             12           Animation,Short
# 4       0      1893     NaN              1              Comedy,Short

# %%
# only include full lenght movies 
basics = basics.loc[basics['titleType']== "movie"]
basics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 299323 entries, 8 to 10130739
# Data columns (total 9 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   tconst          299323 non-null  object
#  1   titleType       299323 non-null  object
#  2   primaryTitle    299323 non-null  object
#  3   originalTitle   299323 non-null  object
#  4   isAdult         299323 non-null  object
#  5   startYear       240569 non-null  object
#  6   endYear         0 non-null       object
#  7   runtimeMinutes  207726 non-null  object
#  8   genres          288681 non-null  object
# dtypes: object(9)
# memory usage: 22.8+ MB

# %%
# drop movies with NA in runtime minutes or genres
basics = basics.dropna(subset = ['runtimeMinutes', 'genres'])
basics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 203837 entries, 8 to 10130615
# Data columns (total 9 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   tconst          203837 non-null  object
#  1   titleType       203837 non-null  object
#  2   primaryTitle    203837 non-null  object
#  3   originalTitle   203837 non-null  object
#  4   isAdult         203837 non-null  object
#  5   startYear       200311 non-null  object
#  6   endYear         0 non-null       object
#  7   runtimeMinutes  203837 non-null  object
#  8   genres          203837 non-null  object
# dtypes: object(9)
# memory usage: 15.6+ MB

# %%
# coerce all to numeric to be able to filter out the years by numbers
basics['startYear']= pd.to_numeric(basics['startYear'], errors= 'coerce')

#Filter the dataframe using startYear. 
#Keep years between 2000-2021 (Including 2000 and 2021)
basics = basics[(basics['startYear'] >= 2000) & (basics['startYear'] <= 2021)]
#Verify the change with .info
basics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 114425 entries, 34800 to 10130615
# Data columns (total 9 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   tconst          114425 non-null  object
#  1   titleType       114425 non-null  object
#  2   primaryTitle    114425 non-null  object
#  3   originalTitle   114425 non-null  object
#  4   isAdult         114425 non-null  object
#  5   startYear       114425 non-null  float64
#  6   endYear         0 non-null       object
#  7   runtimeMinutes  114425 non-null  object
#  8   genres          114425 non-null  object
# dtypes: float64(1), object(8)
# memory usage: 8.7+ MB

# %%
# Exclude movies that are included in the documentary category.

is_documentary = basics['genres'].str.contains('Documentary',case=False)
basics = basics[~is_documentary]
basics.info()

#Eliminate movies that include "Documentary" in the genre
is_documentary = basics['genres'].str.contains('documentary',case=False)
basics = basics[~is_documentary]
#Verify the changes with .info
basics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 81882 entries, 34800 to 10130615
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   tconst          81882 non-null  object
#  1   titleType       81882 non-null  object
#  2   primaryTitle    81882 non-null  object
#  3   originalTitle   81882 non-null  object
#  4   isAdult         81882 non-null  object
#  5   startYear       81882 non-null  float64
#  6   endYear         0 non-null      object
#  7   runtimeMinutes  81882 non-null  object
#  8   genres          81882 non-null  object
# dtypes: float64(1), object(8)
# memory usage: 6.2+ MB

# %% [markdown]
# ### Rating
# Keep only movies that were included in your final title basics dataframe above

# %%
#Keep only movies that were included in your final title basics dataframe
keepers = rating['tconst'].isin(basics['tconst'])
keepers
# Out:
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
#            ...
# 1344596    False
# 1344597    False
# 1344598    False
# 1344599    False
# 1344600    False
# Name: tconst, Length: 1344601, dtype: bool

# %%
#Filter basics
rating = rating[keepers]
#Verify the change
rating.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 68057 entries, 17895 to 1344572
# Data columns (total 3 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   tconst         68057 non-null  object
#  1   averageRating  68057 non-null  float64
#  2   numVotes       68057 non-null  int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 2.1+ MB

# %% [markdown]
# ### Save data in new file

# %%
#Save basics as csv.gz file
basics.to_csv("Data/title_basics_final.csv.gz",compression='gzip',index=False)

# %%
#Open saved file and preview again
basics = pd.read_csv("Data/title_basics_final.csv.gz", low_memory = False)
basics.head()
# Out:
#       tconst titleType                                       primaryTitle  \
# 0  tt0035423     movie                                     Kate & Leopold
# 1  tt0062336     movie  The Tango of the Widower and Its Distorting Mi...
# 2  tt0068865     movie                                Lives of Performers
# 3  tt0069049     movie                         The Other Side of the Wind
# 4  tt0088751     movie                                  The Naked Monster
#
#                                originalTitle  isAdult  startYear  endYear  \
# 0                             Kate & Leopold        0     2001.0      NaN
# 1  El tango del viudo y su espejo deformante        0     2020.0      NaN
# 2                        Lives of Performers        0     2016.0      NaN
# 3                 The Other Side of the Wind        0     2018.0      NaN
# 4                          The Naked Monster        0     2005.0      NaN
#
#    runtimeMinutes                  genres
# 0             118  Comedy,Fantasy,Romance
# 1              70                   Drama
# 2              90                   Drama
# 3             122                   Drama
# 4             100    Comedy,Horror,Sci-Fi

# %%
#Save rating to a compressed file
rating.to_csv("Data/title_ratings_final.csv.gz",compression='gzip',index=False)

# %%
#Open saved file
basics = pd.read_csv("Data/title_ratings_final.csv.gz", low_memory = False)
basics.head()
# Out:
#       tconst  averageRating  numVotes
# 0  tt0035423            6.4     87452
# 1  tt0062336            6.4       179
# 2  tt0068865            5.4        74
# 3  tt0069049            6.7      7811
# 4  tt0088751            5.2       339

# %%
#Save akas as csv.gz file
akas.to_csv("Data/title_akas_final.csv.gz",compression='gzip',index=False)
akas.head()
# Out:
#      titleId  ordering                   title region language        types  \
# 0  tt0000001         6              Carmencita     US      NaN  imdbDisplay
# 1  tt0000002         7  The Clown and His Dogs     US      NaN          NaN
# 2  tt0000005        10        Blacksmith Scene     US      NaN  imdbDisplay
# 3  tt0000005         1     Blacksmithing Scene     US      NaN  alternative
# 4  tt0000005         6     Blacksmith Scene #1     US      NaN  alternative
#
#               attributes isOriginalTitle
# 0                    NaN               0
# 1  literal English title               0
# 2                    NaN               0
# 3                    NaN               0
# 4                    NaN               0
